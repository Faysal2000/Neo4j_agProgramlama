# %%
import csv
from itertools import zip_longest

import requests
from bs4 import BeautifulSoup

# %%
result = requests.get("https://akademik.yok.gov.tr/AkademikArama/view/universityListview.jsp")

# %%
src = result.content
soup=BeautifulSoup(src,"lxml")

# %%
soup
# Out:
# <!DOCTYPE html>
# <html>
# <head>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <meta content="YÖK Akademik Arama" name="description"/>
# <meta content="AYDIN EMRE CEVİZ, MUSTAFA IŞIK" name="author"/>
# <link href="./images/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
# <title>YÜKSEKÖĞRETİM KURULU</title>
# <!-- CSS -->
# <link href="../css/bootstrap.css" rel="stylesheet"/>
# <link href="../css/custom.css?v=2218" rel="stylesheet"/>
# <link href="../css/bootstrapValidator.css" rel="stylesheet"/>
# <!-- Hata ayıklama ie! -->
# <!--[if lt IE 9]><script src="../../assets/js/ie8-responsive-file-warning.js"></script><![endif]-->
# <!-- HTML5 shim and Respond.js IE8 support of HTML5 elements and media queries -->
# <!--[if lt IE 9]>
#       <script src="https://oss.maxcdn.com/libs/html5shiv/3.7.0/html5shiv.js"></script>
# ...

# %%
universiteler= soup.find_all("td")

# %%
un_adi = []
un_sehir = []
un_devlet = []
un_yil = []
un_hoca = []

# %%
for i in range(len(universiteler)):
  un_list.append(universiteler[i].text.strip())
  print("element", i, "  :", universiteler[i].text.strip())

  if i % 5 == 0:
    un_adi.append(universiteler[i].text.strip())
  elif i % 5 == 1:
    un_sehir.append(universiteler[i].text.strip())
  elif i % 5 == 2:
    un_devlet.append(universiteler[i].text.strip())
  elif i % 5 == 3:
    un_yil.append(universiteler[i].text.strip())
  else:
    un_hoca.append(universiteler[i].text.strip())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 2
#       1 for i in range(len(universiteler)):
# ----> 2   un_list.append(universiteler[i].text.strip())
#       3   print("element", i, "  :", universiteler[i].text.strip())
#       5   if i % 5 == 0:
#
# NameError: name 'un_list' is not defined
